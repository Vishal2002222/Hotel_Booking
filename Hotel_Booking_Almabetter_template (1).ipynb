# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
# ##### **Contribution**    - Individual
# ##### **Solo Member Name**: Vishal Ashok Chaudhari

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ### Project Summary: Hotel Booking Analysis
#
# This project presents a comprehensive analysis of hotel booking data, focusing on two types of hotels: City Hotel and Resort Hotel. The objective was to uncover significant trends and insights that can inform strategic decisions for hotel management and marketing. The dataset encompasses various booking details, guest demographics, stay durations, and financial metrics.
#
# #### Data Cleaning and Preprocessing
#
# The initial dataset required substantial cleaning and preprocessing to ensure accuracy and relevance:
#
# 1. **Renaming Columns**: To enhance clarity, the 'adr' column was renamed to 'Average_Daily_Rate'.
# 2. **Handling Missing Values**: Missing values in key columns ('children', 'company', and 'country') were addressed. The 'children' column was filled with the mean value and converted to an integer. 'Company' was filled with zeros and its data type was adjusted. Missing values in the 'country' column were replaced with 'other'.
# 3. **Removing Duplicates**: The dataset contained 31,994 duplicate rows, which were removed to maintain data integrity.
# 4. **Filtering Invalid Data**: Rows where the total number of adults, children, and babies equaled zero were excluded, as they represent invalid bookings.
#
# These steps ensured that the dataset was clean, with no null values and appropriate data types, ready for detailed analysis.
#
# #### Exploratory Data Analysis (EDA)
#
# The EDA phase aimed to identify patterns and generate insights:
#
# 1. **Booking Distribution**:
#    - City Hotels accounted for 61% of the bookings, with Resort Hotels making up the remaining 39%.
#    - Most guests were from Western European countries, indicating a regional preference.
#
# 2. **Cancellation Analysis**:
#    - City Hotels experienced higher cancellation rates compared to Resort Hotels.
#    - A longer lead time (the period between booking and check-in) correlated with a higher likelihood of cancellation.
#
# 3. **Booking Trends**:
#    - Seasonal trends were evident in booking rates and average daily rates (ADR).
#    - ADR peaked during the summer months (May to August), highlighting high demand.
#    - Conversely, the lowest ADR was observed in November, December, February, and January, marking the off-peak season.
#
# 4. **Stay Duration**:
#    - Short stays (less than 4 days) were more common in City Hotels.
#    - Resort Hotels were preferred for longer stays, indicating different guest preferences.
#
# 5. **Distribution Channels**:
#    - The majority of bookings (80%) were made through travel agents and tour operators (TA/TO).
#    - Direct bookings and corporate channels were less utilized, presenting potential growth areas.
#
# #### Key Insights and Recommendations
#
# Several strategic recommendations emerged from the EDA:
#
# 1. **Target Market Focus**:
#    - Allocate a significant portion of the marketing budget to Western European countries, the primary source of guests.
#
# 2. **Hotel Type Emphasis**:
#    - Focus marketing efforts on City Hotels, which attract more bookings.
#    - Enhance the appeal of Resort Hotels for longer stays through tailored packages and promotions.
#
# 3. **Seasonal Pricing Strategy**:
#    - Implement dynamic pricing strategies to maximize revenue during peak seasons (summer months) and offer discounts during off-peak months to boost occupancy.
#
# 4. **Cancellation Mitigation**:
#    - Develop policies and incentives to reduce cancellations, particularly for bookings with longer lead times.
#    - Offer flexible booking options and clear cancellation policies to improve customer satisfaction.
#
# 5. **Enhancing Distribution Channels**:
#    - Increase direct bookings through the hotel’s website and loyalty programs.
#    - Strengthen relationships with TA/TO while exploring opportunities to diversify distribution channels.
#
# #### Conclusion
#
# This analysis provides a detailed overview of booking trends and guest preferences, offering actionable insights to optimize hotel operations and marketing strategies. By addressing identified patterns and implementing the recommendations, hotels can improve booking rates, reduce cancellations, and enhance overall guest satisfaction. This strategic approach will help hotels to better allocate resources, target the right markets, and optimize pricing strategies throughout the year.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Vishal2002222/Hotel_Booking.git

# %% [markdown]
# ### Other links:
#
# **Project Title: Hotel Booking Analysis**
#
# **1. Project Overview**
#
# - **Project Summary**: [Project Summary Document](https://docs.google.com/document/d/1uKj8cpsVEywUHDqcRGpiiBk3SXHXeYmg/edit?usp=sharing&ouid=116756237891343538908&rtpof=true&sd=true)
# - **Project Detailed PPT**: [Detailed Presentation](https://docs.google.com/presentation/d/1dWRvFwEVg3d4yiVwHVuo2iTTKAUpZZX0/edit?usp=sharing&ouid=116756237891343538908&rtpof=true&sd=true)
#
# **2. Technical Documentation**
#
# - **Project Technical Documentation**: [Technical Documentation](https://docs.google.com/document/d/1ohCkSd-EuXTJ3W150lEg8XulhcdHVdIj/edit?usp=sharing&ouid=116756237891343538908&rtpof=true&sd=true)
#
# **2. Github Repo**
#
# - **Project Github Repo**: [Github Repo](https://github.com/Vishal2002222/Hotel_Booking/tree/main)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ### Problem Statement: Hotel Booking Analysis
#
# The hospitality industry faces challenges such as high cancellation rates, seasonal booking fluctuations, and the need for effective guest targeting and retention. Despite extensive booking data, extracting actionable insights is complex. This project aims to analyze hotel booking data to address key issues:
#
# 1. **Cancellation Rates**: Identify factors contributing to high cancellations and strategies to mitigate them.
# 2. **Guest Demographics and Preferences**: Understand guest profiles and how they influence booking patterns.
# 3. **Seasonal Trends**: Analyze booking and average daily rate (ADR) variations across months to optimize occupancy and revenue.
# 4. **Booking Channels**: Determine the most effective booking channels and strategies to increase direct bookings.
# 5. **Stay Duration and Hotel Preferences**: Explore how stay durations differ between City Hotels and Resort Hotels and develop tailored promotional strategies.
#
# By tackling these problems, the analysis aims to provide actionable insights for improved hotel operations, targeted marketing, and enhanced guest experiences.

# %% [markdown]
# ### **Business Objective?**

# %% [markdown]
# **The business objective of the "Hotel Booking Analysis" project is to leverage data insights to improve various aspects of hotel management and marketing. This includes reducing cancellation rates by understanding contributing factors, tailoring marketing efforts to match guest preferences, optimizing pricing and promotions based on seasonal trends, enhancing direct booking channels to reduce reliance on third-party agents, and tailoring promotional strategies to attract guests for longer stays. Ultimately, the goal is to enhance operational efficiency and drive revenue growth by making informed decisions based on data analysis.**

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***
#
# 1. **hotel**: Indicates the type of hotel (City Hotel or Resort Hotel).
# 2. **is_canceled**: Specifies whether the booking was canceled (1) or not (0).
# 3. **lead_time**: The number of days between the booking date and the arrival date.
# 4. **arrival_date_year**: The year of the arrival date.
# 5. **arrival_date_month**: The month of the arrival date.
# 6. **arrival_date_week_number**: The week number of the arrival date.
# 7. **arrival_date_day_of_month**: The day of the month of the arrival date.
# 8. **stays_in_weekend_nights**: The number of weekend nights stayed.
# 9. **stays_in_week_nights**: The number of weekday nights stayed.
# 10. **adults**: The number of adults included in the booking.
# 11. **children**: The number of children included in the booking.
# 12. **babies**: The number of babies included in the booking.
# 13. **meal**: The type of meal booked (e.g., Bed & Breakfast, Half board, etc.).
# 14. **country**: The country of origin of the guest.
# 15. **market_segment**: The market segment designation (e.g., Online TA, Offline TA/TO, etc.).
# 16. **distribution_channel**: The distribution channel through which the booking was made.
# 17. **is_repeated_guest**: Indicates whether the booking was made by a repeated guest (1) or not (0).
# 18. **previous_cancellations**: The number of previous bookings that were canceled by the guest.
# 19. **previous_bookings_not_canceled**: The number of previous bookings that were not canceled by the guest.
# 20. **reserved_room_type**: The room type originally reserved by the guest.
# 21. **assigned_room_type**: The room type assigned to the guest at check-in.
# 22. **booking_changes**: The number of changes made to the booking before arrival.
# 23. **deposit_type**: The type of deposit made for the booking.
# 24. **agent**: The ID of the travel agent that made the booking.
# 25. **company**: The ID of the company that made the booking.
# 26. **days_in_waiting_list**: The number of days the booking was on the waiting list before it was confirmed.
# 27. **customer_type**: The type of booking customer (e.g., Contract, Group, Transient, etc.).
# 28. **adr**: The average daily rate (the average revenue per room per day).
# 29. **required_car_parking_spaces**: The number of car parking spaces requested by the guest.
# 30. **total_of_special_requests**: The total number of special requests made by the guest.
# 31. **reservation_status**: The reservation status (e.g., Check-Out, Canceled, etc.).
# 32. **reservation_status_date**: The date at which the reservation status was updated.
#
# This dataset contains comprehensive information about hotel bookings, guest demographics, booking details, and more, which can be analyzed to derive valuable insights for hotel management and marketing strategies.

# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

image_link = 'https://drive.google.com/uc?id=1HniT3B_Mmc2Z-UbZrkm5Wr387YXyX80v'
response = requests.get(image_link)
img = Image.open(BytesIO(response.content))
aspect_ratio = img.width / img.height
plt.figure(figsize=(10 * aspect_ratio, 10))
plt.imshow(img)
plt.axis('off')  
plt.show()

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
#Importing Required Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
#Acess & Reading the data file
Hotel_booking_df=pd.read_csv("https://drive.google.com/uc?id=1YwOjg6sgXXabuX6yT0DBAf5U4I5Hy3i6")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
#Checking the Data
Hotel_booking_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
Hotel_booking_df.shape #We have 11,93,90 Rows and 32 Columns
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Hotel_booking_df.info() #Overview of the Data with columns and datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Top 10 Rows of the Dataset

# %%
#First 10 Rows
Hotel_booking_df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %% [markdown]
# #### Last 10 rows of the Datset

# %%
#Last 10 Rows
Hotel_booking_df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %% [markdown]
# #### Creating a Copy of orginal dataset for maintaining the orginal one

# %%
Hotel_df = Hotel_booking_df.copy() #Creating a Copy of orginal dataset for maintaining the orginal one

# %%
Hotel_df #Checking
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
Hotel_df[Hotel_df.duplicated()].shape   #There are 31994 Duplicate rows in our dataset
# Out:
# (31994, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = Hotel_df.isna().sum().sort_values(ascending=False) # gives the count of null values in all column

# %%
# Visualizing the missing values
missing_values
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer : The dataset contains detailed information about hotel bookings, including booking status (canceled or not), lead time, arrival date details (year, month, week number, day of month), duration of stay (weekend nights and weekday nights), guest demographics (adults, children, babies), meal type, country of origin, market segment, distribution channel, previous booking history, room types, booking changes, deposit type, agent and company IDs, waiting list duration, customer type, average daily rate, car parking requirements, special requests, reservation status, and reservation status date. This rich dataset provides a comprehensive view of hotel booking activities and guest preferences, enabling in-depth analysis to optimize hotel operations and marketing strategies.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# #### List of the Dataset Columns

# %%
# Dataset Columns
list(Hotel_booking_df.columns) #List of Columns Present in the Data
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %%
# Dataset Describe
Hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Importing datetime module to filter out date columns
from datetime import datetime

# List of date columns
date_columns = ['arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'reservation_status_date']

# Loop through each column in the dataset
for column in Hotel_df.select_dtypes(include=['object']).columns:
    if column not in date_columns:
        unique_values = Hotel_df[column].unique()
        print(f"Unique values for column '{column}': {unique_values}\n")
# Out:
# Unique values for column 'hotel': ['Resort Hotel' 'City Hotel']
#
# Unique values for column 'meal': ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
# Unique values for column 'country': ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
#  'NPL' 'BHS' 'MAC' 'TGO' 'TWN' 'DJI' 'STP' 'KNA' 'ETH' 'IRQ' 'HND' 'RWA'
# ...

# %% [markdown]
# #### Let's enhance the data comprehension by renaming the 'adr' column to 'Average_daily_rate'.

# %%
# Renaming the 'adr' column to 'Average_daily_rate'
Hotel_df.rename(columns={'adr': 'Average_daily_rate'}, inplace=True)

# %%
list(Hotel_df.columns)#Checking the column name is changed or not
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'Average_daily_rate',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %% [markdown]
# #### Here we can see that the column name is updated

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# #### 1) Given the presence of null values in certain columns (specifically, 'agent', 'children', 'company', and 'country'), we will address these missing values by replacing them appropriately and adjusting the data types of selected columns.

# %%
#Replacing the null values
Hotel_df['children'].fillna(Hotel_df.children.mean(),inplace=True)   #Filling null values by mean of the childrens
Hotel_df['children'] = Hotel_df['children'].astype(int)              #Changing the datatype of the column
Hotel_df['company'].fillna(0,inplace=True)                           #filling the 0 to the null values of the column company
Hotel_df['company']=Hotel_df['company'].astype(int)                  #changing the datatype of the column
Hotel_df['country'].fillna('other',inplace=True)                     #Filling other which are null in the column of country

# %% [markdown]
# #### Droping the Duplicate Rows for the Dataset

# %%
Hotel_df[Hotel_df.duplicated()].shape   #There are 31994 Duplicate rows in our dataset
# Out:
# (31994, 32)

# %%
Hotel_df.drop_duplicates(inplace=True)  #Droping Dupliactes from our dataset

# %%
Hotel_df.shape                          #Checking the the rows are dropped or not
# Out:
# (87396, 32)

# %%
Hotel_df.info() #Checking the information of the modified dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %% [markdown]
# #### Now, We can see that there is no any null values and all datatype are in proper format

# %%
Hotel_df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# ####  There are some rows with total number of adults, children or babies equal to zero So we will remove such rows.

# %%
Hotel_df[Hotel_df[['babies', 'adults', 'children']].sum(axis=1) == 0].shape
# Out:
# (166, 32)

# %%
Hotel_df = Hotel_df.drop(Hotel_df[(Hotel_df.babies + Hotel_df.adults + Hotel_df.children) == 0].index)  #Removing rows where Sum of Babies and adult is zero

# %%
Hotel_df.shape
# Out:
# (87230, 32)

# %% [markdown]
# #### Now, our next step involves the removal of outliers from the dataset. Additionally, we will introduce some new columns to facilitate a more comprehensive analysis of the data.

# %%
# Creating a new column 'kids' by summing up the 'children' and 'babies' columns
Hotel_df['kids'] = Hotel_df['children'] + Hotel_df['babies']

# Creating a new column 'Full_stay' by summing up the 'stays_in_weekend_nights' and 'stays_in_week_nights' columns
Hotel_df['Full_stay'] = Hotel_df['stays_in_weekend_nights'] + Hotel_df['stays_in_week_nights']

## Adding New Column Total Member
Hotel_df['Total_members'] = Hotel_df.adults + Hotel_df.babies + Hotel_df.children

# %%
Hotel_df #Checking column is added or not
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# #### Removing an outlier from Average_daily_rate column by usning Scatter plot technique will dump the points which are out of range into a particular range like winsorization

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Full_stay', y='Average_daily_rate', data=Hotel_df)
plt.xlabel('Full Stay (Weekend Nights + Week Nights)')
plt.ylabel('Average Daily Rate')
plt.title('Scatter Plot of Full Stay vs Average Daily Rate')
plt.show()

# %%
Hotel_df.drop(Hotel_df[Hotel_df['Average_daily_rate'] > 5000].index, inplace=True)# Removing all values > 5000

# %%
#Plotting a scatter plot again for checking the outliers removed or not
plt.figure(figsize = (10,6))
sns.scatterplot(y = 'Average_daily_rate', x = 'Full_stay', data = Hotel_df)
plt.show()

# %% [markdown]
# #### Now we can see that all values are in specific range

# %% [markdown]
# #### In the scatter plot, we observe a clear trend: as the length of stay (Full_stay) increases, the average daily rate (Average_daily_rate) tends to decrease. This suggests that customers could potentially secure better deals or discounts for longer stays.

# %% [markdown]
# #### Removing outliers from 'stays_in weekend_nights' and 'stays_in_week_nights

# %%
# Extracting data for the scatter plot
y = Hotel_df['stays_in_weekend_nights']
# Creating the scatter plot
plt.scatter(range(len(y)), y, color='blue', alpha=0.5)
plt.xlabel('Data Points')
plt.ylabel('Number of Weekend Nights Stayed')
plt.show()

# %%
Hotel_df.loc[Hotel_df.stays_in_weekend_nights >= 5,'stays_in_weekend_nights']=  5  #greater than 5 stays are assigned to 5 stays

# %%
# Extracting data for the scatter plot
y = Hotel_df['stays_in_weekend_nights']
# Creating the scatter plot
plt.scatter(range(len(y)), y, color='blue', alpha=0.5)
plt.xlabel('Data Points')
plt.ylabel('Number of Weekend Nights Stayed')
plt.show()

# %% [markdown]
# #### Here we can say that all the values are in specific range

# %% [markdown]
# #### Outliers removed form stays_in_week_nights column

# %%
# Extracting data for the scatter plot
y = Hotel_df['stays_in_week_nights']
# Creating the scatter plot
plt.scatter(range(len(y)), y, color='blue', alpha=0.5)
plt.xlabel('Data Points')
plt.ylabel('Number of Weekend Nights Stayed')
plt.show()

# %%
Hotel_df.loc[Hotel_df.stays_in_week_nights >= 10,'stays_in_week_nights']= 10  #greater than 10 stays are assigned to 10 stays

# %%
# Extracting data for the scatter plot
y = Hotel_df['stays_in_week_nights']
# Creating the scatter plot
plt.scatter(range(len(y)), y, color='blue', alpha=0.5)
plt.xlabel('Data Points')
plt.ylabel('Number of Weekend Nights Stayed')
plt.show()

# %% [markdown]
# #### Removing Outliers from Total Member column

# %%
plt.scatter(range(len(Hotel_df)), Hotel_df['Total_members'], alpha=0.5)
plt.title('Scatter Plot of Total Members')
plt.xlabel('Index')
plt.ylabel('Total Members')
plt.show()

# %%
Hotel_df.loc[Hotel_df.Total_members > 20, 'Total_members'] = 20  #Removing outliers

# %%
plt.scatter(range(len(Hotel_df)), Hotel_df['Total_members'], alpha=0.5)
plt.title('Scatter Plot of Total Members')
plt.xlabel('Index')
plt.ylabel('Total Members')
plt.show()

# %% [markdown]
# #### Now we reomved outliers from all required columns

# %%
Hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87229 entries, 0 to 119389
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87229 non-null  object
#  1   is_canceled                     87229 non-null  int64
#  2   lead_time                       87229 non-null  int64
#  3   arrival_date_year               87229 non-null  int64
#  4   arrival_date_month              87229 non-null  object
#  5   arrival_date_week_number        87229 non-null  int64
#  6   arrival_date_day_of_month       87229 non-null  int64
#  7   stays_in_weekend_nights         87229 non-null  int64
#  8   stays_in_week_nights            87229 non-null  int64
#  9   adults                          87229 non-null  int64
#  10  children                        87229 non-null  int64
#  11  babies                          87229 non-null  int64
# ...

# %% [markdown]
# #### Lets first find the correlation between the numerical data. Also, we have added Full_stay and Total_members columns. So, we can remove adults, children, babies, stays_in_weekend_nights, stays_in_week_nights columns.

# %%
Corr_df = Hotel_df[['lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','Average_daily_rate','required_car_parking_spaces','total_of_special_requests','Full_stay','Total_members']]

# %%
corr_mat = Corr_df.corr()
f, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(corr_mat,vmax=0.8,annot = True,fmt='.2f');

# %% [markdown]
# 1) There appears to be a slight correlation between the length of stay (Full_stay) and lead time, suggesting that for longer hotel stays, people tend to plan slightly closer to the actual arrival date.
#
# 2) There is also a slight correlation between the average daily rate (Average_daily_rate) and the total number of members (Total_members). This correlation is logical, as a higher number of people typically results in more revenue, thus influencing the average daily rate.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Manipulations Performed:
#
# **Handling Missing Values:**
# - Replaced missing values in columns like `agent`, `children`, `company`, and `country` with appropriate substitutes.
#
# **Data Type Conversion:**
# - Converted data types of certain columns for better analysis.
#
# **Feature Engineering:**
# - Created new columns such as `kids` (sum of children and babies) and `Full_stay` (sum of weekend and week night stays).
# - Renamed `adr` column to `Average_Daily_Rate` for clarity.
#
# **Outlier Removal:**
# - Identified and removed outliers to improve the quality of the analysis.
#
# **Correlation Analysis:**
# - Analyzed correlations between variables like `Full_stay`, `lead_time`, `Average_Daily_Rate`, and `Total_members`.
#
# **Insights Found:**
#
# - **Missing Values:**
#   - Identified missing values in columns like `agent`, `children`, `company`, and `country`.
#   - Replaced missing values with appropriate substitutes to ensure data integrity.
#
# - **Outliers:**
#   - Detected outliers in certain numerical columns through visualization and statistical methods.
#   - Removed outliers to prevent them from skewing the analysis and impacting model performance.
#
# - **Correlation Analysis:**
#   - Discovered correlations between various features such as `Full_stay`, `lead_time`, `Average_Daily_Rate`, and `Total_members`.
#   - Found that `Full_stay` length and `lead_time` have a slight correlation, suggesting that longer hotel stays are often planned with less lead time.
#   - Observed a slight correlation between `Average_Daily_Rate` and `Total_members`, indicating that the number of people in a booking may influence the average daily rate.
#
# - **Feature Engineering:**
#   - Engineered new features such as `kids` (sum of children and babies) and `Full_stay` (sum of weekend and week night stays) to provide additional insights into the data.
#
# - **Data Quality Enhancement:**
#   - Improved data quality by converting data types of certain columns for better analysis and interpretation.
#   - Renamed columns like `adr` to `Average_Daily_Rate` to enhance clarity and understanding.

# %% [markdown]
# #### Creating a subset of city and resort dataframe

# %%
City_df =pd.DataFrame(Hotel_df[Hotel_df['hotel'] =='City Hotel'])
Resort_df =pd.DataFrame(Hotel_df[Hotel_df['hotel'] =='Resort Hotel'])

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# #### Meal, Hotel, Booking Distribution Pie charts

# %% [markdown]
# #### There is a two type of Hotel Which are Resort and City Hotels

# %%
Hotel_Type=Hotel_df['hotel'].value_counts()
Hotel_Type
# Out:
# hotel
# City Hotel      53273
# Resort Hotel    33956
# Name: count, dtype: int64

# %%
meal_type = Hotel_df['meal'].value_counts()
meal_type
# Out:
# meal
# BB           67906
# SC            9391
# HB            9080
# Undefined      492
# FB             360
# Name: count, dtype: int64

# %%
Booking_Distribution_channel_Type=Hotel_df['distribution_channel'].value_counts()
Booking_Distribution_channel_Type
# Out:
# distribution_channel
# TA/TO        69027
# Direct       12954
# Corporate     5062
# GDS            181
# Undefined        5
# Name: count, dtype: int64

# %%
# Custom colors
hotel_colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
meal_colors = ['#c2c2f0','#ffb3e6','#c4e17f','#f5c518']
channel_colors = ['#ffb3b3','#c0e6f5','#ffcc99','#8c564b']

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plotting the first pie chart
axes[0].pie(Hotel_Type, labels=Hotel_Type.index, autopct='%1.1f%%', startangle=140, colors=hotel_colors)
axes[0].set_title('Hotel Types Distribution', fontsize=14, fontweight='bold')
axes[0].axis('equal')

# Plotting the second pie chart
axes[1].pie(meal_type, labels=meal_type.index, autopct='%1.1f%%', startangle=140, colors=meal_colors)
axes[1].set_title('Meal Types Distribution', fontsize=14, fontweight='bold')
axes[1].axis('equal')

# Plotting the third pie chart with custom colors
axes[2].pie(Booking_Distribution_channel_Type, labels=Booking_Distribution_channel_Type.index, autopct='%1.1f%%', startangle=140, colors=channel_colors)
axes[2].set_title('Booking Distribution Channel Type', fontsize=14, fontweight='bold')
axes[2].axis('equal')

# Display the plot with tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are great for showing how different categories compare to the whole. They make it easy to see the proportions of hotel types, meal types, and booking channels at a glance. Their round shape helps us quickly understand the relative sizes of each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The data illustrates that 61% of the accommodations are city hotels, while 39% are resort hotels.
#
# 2. The meal preferences breakdown stands as follows: BB signifies bed and breakfast, HB denotes half board (inclusive of breakfast and dinner), and FB represents full board (inclusive of breakfast, lunch, and dinner). It's evident that 78% of individuals opt for the 'BB' meal plan.
#
# 3. The majority, accounting for 79% of respondents, favor booking through 'TA/TO' channels.
#
# 4. Merely 4% of individuals are returning guests, indicating a notably low guest retention rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Positive Business Impact:
# 1. **Targeted Marketing**: Focus on promoting city hotels and 'BB' meal plans to match guest preferences.
# 2. **Channel Optimization**: Enhance partnerships with 'TA/TO' booking channels, which account for 79% of bookings.
# 3. **Customer Retention**: Develop loyalty programs to improve the low 4% guest return rate.
#
# ### Negative Growth Insight:
# - **Low Guest Retention**: The 4% return rate suggests issues in guest satisfaction, which can harm long-term growth. Improving the guest experience is essential for better retention and sustainable growth.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# #### Pie chart of repeated guest, customer type, required car parking space

# %%
repeated_guest = Hotel_df['is_repeated_guest'].value_counts()
repeated_guest
# Out:
# is_repeated_guest
# 0    83865
# 1     3364
# Name: count, dtype: int64

# %%
customer_type = Hotel_df['customer_type'].value_counts()
customer_type
# Out:
# customer_type
# Transient          71861
# Transient-Party    11692
# Contract            3135
# Group                541
# Name: count, dtype: int64

# %%
car_parking = Hotel_df['required_car_parking_spaces'].value_counts()
car_parking
# Out:
# required_car_parking_spaces
# 0    79923
# 1     7273
# 2       28
# 3        3
# 8        2
# Name: count, dtype: int64

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plotting the first pie chart (Repeated Guest Distribution)
axes[0].pie(repeated_guest, labels=repeated_guest.index, autopct='%1.0f%%', startangle=140, colors=['#66c2a5', '#fc8d62'])
axes[0].set_title('Repeated Guest Distribution', fontsize=16, fontweight='bold')

# Plotting the second pie chart (Customer Type)
axes[1].pie(customer_type, labels=customer_type.index, autopct='%1.0f%%', startangle=140, colors=['#8da0cb', '#e78ac3', '#a6d854'])
axes[1].set_title('Customer Type', fontsize=16, fontweight='bold')

# Plotting the third pie chart (Required Parking Spaces)
Car_parking_spaces = Hotel_df['required_car_parking_spaces'].value_counts()
axes[2].pie(Car_parking_spaces, labels=Car_parking_spaces.index, autopct='%1.0f%%', startangle=140, colors=['#ffd92f', '#e5f5f9'])
axes[2].set_title('Required Parking Spaces', fontsize=16, fontweight='bold')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts were chosen because they effectively display the proportional distribution of categories. They make it easy to see at a glance which categories are dominant and compare different segments within the data, such as the proportion of repeated guests, customer types, and parking space requirements. This visual clarity helps in quickly identifying key trends and insights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Among the four customer types, the majority fall under the 'Transient' category.
#
# 2. Merely 8% of individuals necessitate parking spaces

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Will the gained insights help create a positive business impact?
# Yes, the insights can positively impact the business. Knowing that the majority of customers are 'Transient' helps tailor marketing strategies and services to their needs, potentially increasing satisfaction and retention. Understanding that only 8% of customers require parking spaces allows the hotel to allocate resources more efficiently, focusing on other amenities that might be more in demand.
#
# #### Are there any insights that lead to negative growth? Justify with specific reasons.
# No specific insights directly suggest negative growth. However, the low percentage of repeated guests (4%) is concerning. It indicates a potential issue with customer satisfaction or loyalty, which could lead to negative growth if not addressed. Improving guest experiences and implementing loyalty programs might mitigate this issue and foster positive growth.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# #### Hotel Wise Bookings based on Daily Month and year

# %% [markdown]
# #### Monthly (City)

# %%
City_arrival_date_month_count=City_df.arrival_date_month.value_counts()
City_arrival_date_month_count
# Out:
# arrival_date_month
# August       6576
# July         5730
# May          5402
# April        5072
# June         4997
# March        4832
# September    4232
# October      4197
# February     3591
# December     2998
# November     2922
# January      2724
# Name: count, dtype: int64

# %% [markdown]
# #### Monthly (Resort)

# %%
Resort_df_arrival_date_month_count=Resort_df.arrival_date_month.value_counts()
Resort_df_arrival_date_month_count
# Out:
# arrival_date_month
# August       4666
# July         4313
# May          2942
# April        2828
# June         2759
# October      2724
# March        2656
# February     2492
# September    2450
# December     2114
# November     2051
# January      1961
# Name: count, dtype: int64

# %% [markdown]
# #### Yearly(Resort)

# %%
resort_counts_arrival_date_year=Resort_df.arrival_date_year.value_counts()
resort_counts_arrival_date_year
# Out:
# arrival_date_year
# 2016    15629
# 2017    11569
# 2015     6758
# Name: count, dtype: int64

# %% [markdown]
# #### Yearly(City)

# %%
city_counts_arrival_date_year=City_df.arrival_date_year.value_counts()
city_counts_arrival_date_year
# Out:
# arrival_date_year
# 2016    26683
# 2017    20064
# 2015     6526
# Name: count, dtype: int64

# %% [markdown]
# #### Plot of Daily Booking in a month Resort and City Both Hotels

# %%
# Create count plot
plt.figure(figsize=(14, 5))
sns.countplot(x='arrival_date_day_of_month', data=Hotel_df, hue='hotel', palette='viridis')
plt.title('Daily Booking', fontweight="bold", size=20, color='blue')
plt.xlabel('Daily', fontweight="bold", size=12)
plt.ylabel('Count', fontweight="bold", size=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - The specific chart was chosen to visualize the daily booking trends of city hotels and resort hotels throughout the month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The insight derived from the chart indicates that the daily booking count for city hotels is consistently higher than that of resort hotels across all 31 days of the month. Additionally, there is a noticeable decrease in the number of bookings towards the end of the month.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The insights obtained from the chart can aid in strategic decision-making for optimizing hotel bookings. The consistently higher daily booking count for city hotels suggests a higher demand in urban areas, prompting the allocation of resources and marketing efforts accordingly. However, the observed decline in bookings towards the end of the month may indicate a need for targeted promotional campaigns or incentives to stimulate bookings during these periods and mitigate potential negative growth.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# #### Plot of Booking By Month

# %%
# Creating count plot
plt.figure(figsize=(12, 8))
sns.countplot(x='arrival_date_month', data=Hotel_df, hue='hotel', palette='muted')
plt.title('Bookings by Month', fontweight="bold", size=20, color='navy')
plt.xlabel('Month', fontweight="bold", size=12)
plt.ylabel('Count', fontweight="bold", size=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#    - The count plot was chosen because it effectively visualizes the distribution of bookings across different months, segmented by hotel type. This allows for a clear comparison of booking patterns over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#    - The chart reveals that there is a greater number of customers arriving during the months of March, April, May, June, and July, particularly during the summer season. This trend is observed for both city hotels and resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#    - Yes, the insights gained from the chart can contribute to creating a positive business impact. By identifying the peak booking months, hotels can anticipate higher demand during these periods and adjust their operations accordingly. This may involve increasing staff levels, optimizing inventory management, and implementing targeted marketing strategies to capitalize on the influx of customers. However, there may be challenges associated with managing peak periods, such as ensuring sufficient resources and preventing overbooking, which need to be addressed to avoid negative impacts on business growth.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# #### Plot of the Year

# %%
# Create count plot
plt.figure(figsize=(12, 8))
sns.countplot(x='arrival_date_year', data=Hotel_df, hue='hotel', palette='Set2')
plt.title('Bookings by Year', fontweight="bold", size=20, color='navy')
plt.xlabel('Year', fontweight="bold", size=12)
plt.ylabel('Count', fontweight="bold", size=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#   - The count plot effectively visualizes the distribution of bookings over different years, allowing for a clear comparison between city hotels and resort hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#    - The chart reveals that bookings for city hotels consistently exceed those for resort hotels across the years. Both types of hotels experienced their highest booking volumes in 2016, indicating a potential peak in demand during that year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, these insights can have a positive business impact by informing strategic decisions related to resource allocation, marketing strategies, and pricing policies. Understanding the peak booking periods can help hotels optimize their operations and maximize revenue during high-demand seasons.

# %% [markdown]
# #### We need to use vlaues_count fuction for the pie chart but not need for bar plot we can use the sns count in the bar plot it automatically count the unique values and sum there like group by using sns count plot
# Like this Create count plot plt.figure(figsize=(12, 8)) sns.countplot(x='arrival_date_year', data=Hotel_df, hue='hotel') plt.title('Bookings by Year', fontweight="bold", size=20) plt.xlabel('Year') plt.ylabel('Count') plt.xticks(rotation=45) plt.show()

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# #### Line Chart trend over the time

# %%
#Which month get most visitors?
resort_guest = Resort_df['arrival_date_month'].value_counts().reset_index()
resort_guest.columns=['month','no of guests']
resort_guest

city_guest = City_df['arrival_date_month'].value_counts().reset_index()
city_guest.columns=['month','no of guests']
city_guest

final_guest=resort_guest.merge(city_guest, on = 'month')                              #merge resort guest and city guest month wise
final_guest.columns=['month','no of guests in resort','no of guest in city hotel']
final_guest
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
final_guest['month'] = pd.Categorical(final_guest['month'], categories=months, ordered=True)

#Which month get most visitors?
plt.figure(figsize =(15,8))
sns.lineplot(data=final_guest, x='month', y='no of guests in resort', marker ='^')
sns.lineplot(data=final_guest, x='month', y='no of guest in city hotel',marker ='^')
plt.legend(['Resort','City Hotel'])
plt.ylabel('Number of guest')
# Out:
# Text(0, 0.5, 'Number of guest')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I chose a line plot to visualize the trend of visitor numbers over different months for resort and city hotels. A line plot is suitable for showing trends over time or in this case, across different months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The insight from the chart indicates that June, July, August, and September consistently have the highest number of visitors for both resort and city hotels. These months likely correspond to peak vacation times, such as the summer season, leading to increased tourist activity and hotel bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, the gained insights can help create a positive business impact by allowing hotel management to better allocate resources, plan staffing levels, and tailor marketing strategies to capitalize on peak tourist seasons. However, if the hotels are unable to meet the increased demand during these peak months, it could lead to negative growth due to potential customer dissatisfaction, missed revenue opportunities, and reputational damage. Therefore, it's essential for hotels to ensure they have the capacity to accommodate the influx of visitors during these high-demand periods.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# #### Plot of Country wise guest distribution

# %%
unique_countries = Hotel_df['country'].unique()
print(unique_countries)
# Out:
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'other' 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
#  'NPL' 'BHS' 'MAC' 'TGO' 'TWN' 'DJI' 'STP' 'KNA' 'ETH' 'IRQ' 'HND' 'RWA'
#  'KHM' 'MCO' 'BGD' 'IMN' 'TJK' 'NIC' 'BEN' 'VGB' 'TZA' 'GAB' 'GHA' 'TMP'
#  'GLP' 'KEN' 'LIE' 'GNB' 'MNE' 'UMI' 'MYT' 'FRO' 'MMR' 'PAN' 'BFA' 'LBY'
# ...

# %%
top_countries = Hotel_df['country'].value_counts().head(15) #only taking top 15 countries
top_countries

plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')
plt.xlabel('Number of Hotels')
plt.ylabel('Country')
plt.title('From which country most of the guesta re comming?')
plt.show()

#in this we not used sns count beacause the unique value is so more than 100 so that we chhose only top 15
# Out:
# <ipython-input-300-d57376d5bf69>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I chose a horizontal bar plot to visualize the distribution of hotel guests by country. A bar plot is effective for comparing the frequency of occurrences across different categories, in this case, countries. Using a horizontal layout allows for better readability when dealing with longer category names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The analysis reveals that most guests are from Portugal, followed by other European countries such as the United Kingdom, France, and Spain. This suggests that the majority of the hotel's clientele comes from within Europe, indicating potential opportunities for targeted marketing and promotional efforts in these regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, the insights gained from analyzing the top countries of origin for hotel guests can help create a positive business impact. By identifying the primary sources of clientele, hotel management can tailor their services, amenities, and marketing strategies to better cater to the preferences and needs of guests from these countries. However, over-reliance on a specific market segment, such as guests from Portugal or Europe, could pose a risk in the event of economic downturns or shifts in travel trends, potentially leading to negative growth if the hotel fails to diversify its customer base.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# #### Plot of Distribution of total member in pair

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=Hotel_df, x='Total_members')
plt.xlabel('Total Members')
plt.ylabel('Count')
plt.title('Distribution of Total Members')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I chose a count plot to visualize the distribution of total members per booking. A count plot is suitable for displaying the frequency of occurrences of each category within a single categorical variable, in this case, the total number of members per booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The analysis indicates that the majority of guests prefer to book accommodations for two adults, as evidenced by the peak count at 'Total Members' equal to 2. This suggests that most bookings are made by couples or pairs of individuals traveling together.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, the insights regarding the distribution of total members per booking can help create a positive business impact. Understanding the typical group size of guests allows hotel management to optimize room configurations, tailor amenities, and develop targeted promotional packages to better accommodate the needs and preferences of couples and pairs of travelers. However, there may be potential challenges in accommodating larger groups or families if the hotel's infrastructure and services are primarily designed for smaller parties, which could limit growth opportunities in segments requiring accommodations for larger groups.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# #### Which agent made the maximum bookings?

# %%
top_agents=Hotel_df['agent'].value_counts().head(10).sort_values()
top_agents
# Out:
# agent
# 6.0       1117
# 1.0       1228
# 8.0       1383
# 28.0      1493
# 241.0     1644
# 250.0     2779
# 7.0       3294
# 14.0      3342
# 240.0    13028
# 9.0      28721
# Name: count, dtype: int64

# %%
# Get the top 5 performing agents
top_agents = Hotel_df['agent'].value_counts().head(5)

# Plotting
plt.figure(figsize=(10, 5))
sns.barplot(x=top_agents.index, y=top_agents.values, palette='viridis')
plt.title('Top 5 Performing Agents', fontweight="bold", size=20, color='navy')
plt.xlabel('Agent', fontweight="bold", size=12)
plt.ylabel('Number of Bookings', fontweight="bold", size=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-303-8290174a3fb9>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_agents.index, y=top_agents.values, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I selected a bar plot to visualize the number of bookings made by each agent. A bar plot effectively displays the counts of categorical data (in this case, agent IDs) and allows for easy comparison between different agents.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  - The analysis reveals that Agent No. 9 has made the highest number of bookings among all agents. This suggests that Agent No. 9 may have a strong network or effective sales strategies, resulting in a higher volume of bookings compared to other agents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, the insights regarding the performance of booking agents can help identify top-performing agents and potentially reward or incentivize them to maintain or improve their booking performance. Additionally, understanding which agents contribute the most bookings can inform marketing and partnership strategies to further leverage successful partnerships. However, if there is over-reliance on a single agent or a small group of agents for bookings, it could pose a risk to business stability in the event of changes in agent availability or performance.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# #### Which room is most preferred?

# %%
# Chart - 10 visualization codeplt.figure(figsize=(10, 6))
sns.countplot(data=Hotel_df, x='assigned_room_type')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Most Preferred Romm Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I chose a count plot to visualize the distribution of preferred room types among guests. A count plot is suitable for showing the frequency of each category within a categorical variable, making it easy to identify the most preferred room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The analysis reveals that room types A and D are the most preferred by guests, as they have the highest counts. However, it's important to note that room types H, G, F, and C, which are better in terms of 'Average Daily Rate', are also frequently chosen by guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, understanding the distribution of preferred room types can help hotel management optimize room allocation and pricing strategies. By knowing which room types are in high demand, the hotel can adjust pricing accordingly to maximize revenue. However, if there is a significant mismatch between the preferred room types and the higher-priced rooms, it could lead to negative growth as guests may opt for cheaper alternatives elsewhere

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# #### Stay length in a hotel

# %%
# Filter the dataset to include only non-canceled bookings
active_bookings = Hotel_df[Hotel_df['is_canceled'] == 0]

# Further filter to include only stays of less than 15 days
limited_stays = active_bookings[active_bookings['Full_stay'] < 15]

# Plotting the data
plt.figure(figsize=(10, 5))
sns.countplot(data=limited_stays, x='Full_stay', hue='hotel', palette='Set2')
plt.title('Stay Length in Hotels', fontweight="bold", size=20)
plt.xlabel('Full Stay (Days)', fontweight="bold")
plt.ylabel('Count', fontweight="bold")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I chose the specific chart to visualize the distribution of stay lengths in hotels and understand the booking patterns based on the length of stay.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The insights from the chart reveal that the most common stay length is less than 4 days. Additionally, there is a preference for City hotels for shorter stays, while Resort hotels are favored for longer stays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - These insights can potentially lead to a positive business impact by helping hotel managers optimize room availability and pricing strategies based on the length of stay preferences of their guests. For instance, they can tailor marketing campaigns or offer special packages to attract guests for longer stays in Resort hotels, thus maximizing revenue. However, there might be a negative impact if the hotel infrastructure or services are not well-equipped to handle longer stays, leading to potential dissatisfaction among guests. Thus, it's essential for hotels to align their offerings with the identified preferences while ensuring a positive guest experience across different lengths of stay.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# #### Number of stays in weeekend  nights and weekdays night

# %%
plt.figure(figsize=(15, 8))
# Plotting the first subplot for number of stays on weekend nights
plt.subplot(1, 2, 1)
sns.countplot(x='stays_in_weekend_nights', hue='hotel', data=Hotel_df, palette='cool')
plt.title("Number of stays on weekend nights", fontweight="bold", size=20)
# Plotting the second subplot for number of stays on weekday nights
plt.subplot(1, 2, 2)
sns.countplot(x='stays_in_week_nights', hue='hotel', data=Hotel_df, palette='rainbow_r')
plt.title("Number of stays on weekday nights", fontweight="bold", size=20)
# Showing the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - The chosen chart aims to provide a comparative view of stays on both weekend nights and weekday nights across different types of hotels, facilitating easy observation of booking patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The visualization offers a clear depiction of the distribution of stays for city hotels and resort hotels concerning weekend and weekday nights.
#    - It reveals whether guests exhibit a preference for weekend getaways or weekday stays, and whether this preference varies between hotel types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - These insights can inform marketing strategies and promotional campaigns tailored to attract more guests during specific periods.
#    - For instance, if there's a pronounced preference for weekend stays in resort hotels, targeted marketing initiatives can promote weekend getaway packages to capitalize on this trend.
#    - Conversely, if there's a negative trend such as reduced stays on weekdays across all hotels, it may signal a need to adjust pricing strategies or introduce weekday-specific deals to stimulate demand during off-peak periods.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# #### Most Preferred Boking Type:

# %%
# Chart - 13 visualization code
plt.figure(figsize=(10, 5))
sns.countplot(x='deposit_type', data=Hotel_df, hue='is_canceled', palette='viridis')
plt.title('Booking Preferred with Deposit Type', fontweight="bold", size=15)
plt.xlabel('Deposit Type', fontweight="bold")
plt.ylabel('Count', fontweight="bold")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - The specific chart, a count plot with deposit type on the x-axis and cancellation status on the hue, was chosen to understand the relationship between booking preferences and cancellation behavior based on the deposit type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Most bookings** are made without a deposit ('No Deposit').
# - Surprisingly, there are **cancellations** even with bookings made under the 'Non Refund' deposit type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - These insights can help in making **strategic decisions** regarding deposit policies.
# - While the majority of bookings are made without a deposit, indicating a preference for flexibility, the presence of cancellations in the 'Non Refund' category suggests a potential area for improvement.
# - Adjusting deposit policies or offering incentives for non-refundable bookings may help mitigate cancellations and contribute to a **positive business impact** by reducing revenue loss.
# - However, the potential **negative impact** of stricter deposit policies, such as deterring potential guests or reducing overall bookings, should also be considered and balanced with the benefits.

# %% [markdown]
# #### Chart - 14

# %% [markdown]
# #### Which Hotel have longer waiting time?

# %%
grouped_by_hotel = Hotel_df.groupby('hotel')  # Creating a DataFrame which stores groupby 'Hotel' rows
# waiting_df which stores mean of days in waiting list column
waiting_df = pd.DataFrame(grouped_by_hotel['days_in_waiting_list'].agg(np.mean).reset_index().rename(columns={'days_in_waiting_list': 'avg_waiting_period'}))
plt.figure(figsize=(8, 8))
sns.barplot(x=waiting_df['hotel'], y=waiting_df['avg_waiting_period'], palette='coolwarm')
plt.title('Average Waiting Period by Hotel', fontweight="bold", size=15)
plt.xlabel('Hotel Type', fontweight="bold")
plt.ylabel('Average Waiting Period (Days)', fontweight="bold")
plt.show()
# Out:
# <ipython-input-308-fc488476c3c9>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=waiting_df['hotel'], y=waiting_df['avg_waiting_period'], palette='coolwarm')

# %% [markdown]
# 1. **Why did you pick the specific chart?**
#    - The specific chart, a count plot with deposit type on the x-axis and cancellation status on the hue, was chosen to understand the relationship between booking preferences and cancellation behavior based on the deposit type.
#
# 2. **What is/are the insight(s) found from the chart?**
#    - From the chart, it is evident that most bookings are made without a deposit ('No Deposit'). Surprisingly, there are cancellations even with bookings made under the 'Non Refund' deposit type.
#
# 3. **Will the gained insights help creating a positive business impact?**
#    - The insights gained from this chart can help in making strategic decisions regarding deposit policies. While the majority of bookings are made without a deposit, indicating a preference for flexibility, the presence of cancellations in the 'Non Refund' category suggests a potential area for improvement. Adjusting deposit policies or offering incentives for non-refundable bookings may help mitigate cancellations and contribute to a positive business impact by reducing revenue loss. However, the potential negative impact of stricter deposit policies, such as deterring potential guests or reducing overall bookings, should also be considered and balanced with the benefits.

# %% [markdown]
# #### Chart - 15

# %% [markdown]
# #### Which hotel recives most number os special requests

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=Hotel_df, x='total_of_special_requests', hue='hotel', palette='Set2')
plt.xlabel('Number of Special Requests', fontweight="bold")
plt.ylabel('Count', fontweight="bold")
plt.title('Distribution of Special Requests by Hotel', fontweight="bold", size=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - The specific chart, a count plot with the number of special requests on the x-axis, was chosen to compare the frequency of special requests between city hotels and resort hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - From the chart, it is evident that city hotels receive a higher number of special requests compared to resort hotels. Additionally, the majority of guests, regardless of hotel type, ask for only one special request.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?**
#    These insights provide valuable information about guest preferences and expectations regarding special requests. City hotels may use this information to tailor their services and amenities to better accommodate guests' needs, potentially leading to higher guest satisfaction and positive reviews. By understanding the most common types of special requests and ensuring prompt and efficient fulfillment, hotels can enhance the overall guest experience and establish a reputation for excellent customer service, ultimately driving positive business outcomes.

# %% [markdown]
# #### Chart - 17

# %% [markdown]
# #### Cancelation Rates for particular hotels:

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1,2,1 )
sns.countplot(x='hotel',hue="is_canceled", data=Hotel_df,palette='Pastel1')
plt.title("Cancelation rates in City hotel and Resort hotel",fontweight="bold", size=20)
plt.subplot(1,2,2 )
sns.barplot(x='arrival_date_year', y='lead_time',hue='is_canceled', data= Hotel_df, palette='Pastel1')
plt.title('Arriving year, Cancellations with lead time',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)

# %% [markdown]
# **1. Why did you pick the specific chart?**
#    *Answer:* The count plot was chosen to visually compare the cancellation rates between city hotels and resort hotels, providing a clear understanding of the cancellation behavior by hotel type.
#
# **2. What is/are the insight(s) found from the chart?**
#    *Answer:* The chart reveals that the cancellation rate is higher in city hotels compared to resort hotels. This insight suggests that there might be factors specific to city hotels that contribute to a higher likelihood of cancellations.
#
# **3. Will the gained insights help creating a positive business impact?**
#    *Answer:* Yes, the insights gained from analyzing cancellation rates by hotel type can help hotel management make informed decisions to reduce cancellation rates. By understanding the factors contributing to higher cancellation rates in city hotels, strategies can be devised to address these issues and improve overall booking retention. Implementing measures to minimize cancellations can lead to increased revenue and customer satisfaction.

# %% [markdown]
# #### Avergae daily rate by month

# %%
months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
Hotel_df['arrival_date_month'] = pd.Categorical(Hotel_df['arrival_date_month'], categories=months_order, ordered=True)
Hotel_df_sorted = Hotel_df.sort_values('arrival_date_month')

plt.figure(figsize=(12,5))
sns.lineplot(data=Hotel_df_sorted, x='arrival_date_month', y='Average_daily_rate', hue='hotel', sort=True, marker='^', palette='Set2')
plt.title('Average Daily Rate by Month', fontweight='bold', size=20, color='blue')
plt.xlabel('Month', fontsize=12, color='green')
plt.ylabel('Average Daily Rate', fontsize=12, color='green')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Analysis and impact:
#
# **Insight Analysis:**
# The Average Daily Rate (ADR) exhibits a noticeable increase during the summer season, particularly in the months of June, July, and August. This surge in ADR during the summer months suggests higher demand for accommodations during this period, possibly due to vacation and holiday travel. It indicates that hotels can capitalize on the seasonal demand by adjusting pricing strategies to maximize revenue during peak seasons.
#
# **Business Impact:**
# The gained insight about the seasonal variation in ADR can have a positive impact on business decision-making. Hotels can leverage this information to implement dynamic pricing strategies, offering competitive rates during off-peak seasons to attract more guests while adjusting prices upwards during high-demand periods to maximize profitability. By aligning pricing strategies with seasonal demand trends, hotels can optimize revenue management and enhance overall business performance.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Solution to Business Objective**
#
# **1. Dynamic Pricing Strategies:** Implementing dynamic pricing algorithms can help the hotel adjust room rates based on real-time demand, competitor pricing, and other market factors. By leveraging historical booking data and predictive analytics, hotels can optimize pricing to maximize revenue during peak periods and stimulate demand during off-peak times.
#
# **2. Personalized Marketing Campaigns:** Utilize guest data and insights from CRM systems to create targeted marketing campaigns that resonate with specific customer segments. Personalization can extend beyond promotional offers to include customized recommendations, loyalty rewards, and personalized communication channels such as email marketing and social media outreach.
#
# **3. Enhanced Guest Experience Initiatives:** Investing in enhancing the guest experience can lead to higher satisfaction levels, positive reviews, and increased repeat bookings. This could involve upgrading facilities, providing personalized amenities, offering concierge services, and implementing contactless check-in/check-out options to cater to changing guest preferences and expectations.
#
# **4. Optimized Distribution Strategies:** Evaluate the performance of distribution channels, including online travel agencies (OTAs), direct booking platforms, and global distribution systems (GDS), to identify opportunities for optimization. By diversifying distribution channels and reducing reliance on third-party intermediaries, hotels can improve margins and maintain better control over pricing and inventory management.
#
# **5. Investment in Revenue Management Tools:** Implementing advanced revenue management software and analytics platforms can provide valuable insights into pricing trends, demand forecasting, and competitor benchmarking. These tools enable hotels to make data-driven decisions, optimize pricing strategies, and identify revenue opportunities across different market segments and booking channels.
#
# **6. Focus on Upselling and Cross-Selling:** Encourage upselling and cross-selling opportunities by promoting premium room upgrades, ancillary services, and add-on packages. This can help increase the average spend per guest and drive incremental revenue without significant additional costs.
#
# **7. Promote Direct Bookings:** Offer incentives and benefits to guests who book directly through the hotel's website or mobile app. Direct bookings typically incur lower distribution costs compared to third-party channels, resulting in higher profit margins for the hotel. Loyalty programs, exclusive discounts, and perks such as free Wi-Fi or complimentary breakfast can incentivize guests to book directly.
#
# **8. Continuous Monitoring and Adaptation:** Continuously monitor key performance indicators (KPIs) such as average daily rate (ADR), revenue per available room (RevPAR), and occupancy rates to assess the effectiveness of revenue management strategies. Be prepared to adapt and refine strategies based on changing market dynamics, guest preferences, and competitive landscape.
#
# By implementing these strategies and maintaining a proactive approach to revenue management, hotels can optimize revenue streams, enhance profitability, and achieve their business objectives in a competitive and dynamic market environment.**

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the analysis of the hotel booking dataset has provided valuable insights into booking patterns, guest preferences, and revenue optimization opportunities. By leveraging these insights, hotels can implement targeted strategies to maximize revenue, enhance guest satisfaction, and achieve their business objectives.
#
# Key findings from the analysis include:
# - Identification of peak booking periods and seasonality trends, such as higher booking volumes during the summer months.
# - Analysis of cancellation rates, booking lead times, and deposit types to understand factors influencing booking behavior and revenue volatility.
# - Exploration of customer segmentation, including preferences for room types, meal plans, and special requests, to tailor marketing efforts and enhance guest experiences.
# - Evaluation of pricing strategies, distribution channels, and revenue management techniques to optimize revenue streams and maximize profitability.
#
# Moving forward, hotels should focus on implementing dynamic pricing strategies, personalized marketing campaigns, and enhanced guest experience initiatives to drive revenue growth and competitive advantage. Continuous monitoring of key performance indicators and adaptation of strategies based on market dynamics will be essential to sustain success in an ever-evolving hospitality landscape.
#
# By adopting a data-driven approach and embracing innovative revenue management practices, hotels can thrive in a competitive market environment and deliver exceptional value to guests while achieving their financial goals.**
#
# The majority of guests hail from Western European countries, so it's advisable to allocate a significant portion of our budget to target these regions.
#
# With 61% of bookings for City hotels and 39% for Resort hotels, City hotels clearly see more activity.
#
# City hotels are the predominant choice among booked accommodations, warranting a focus on allocating the majority of our targeting funds to this category.
#
# It's worth concentrating our efforts on advertising to attract new guests, as we lack repeat visitors.
#
# TA/TO accounts for 80% of our distribution channels.
#
# Short stays, typically less than 4 days, are most common, with City hotels being the preferred choice. However, for longer stays, guests tend to favor Resort hotels.
#
# Consider booking during November, December, February, and January for lower average daily rates, avoiding the peak season months of May, June, July, and August.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
